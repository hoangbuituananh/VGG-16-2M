# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.utils.class_weight import compute_class_weight

# %%
data_dir_train = "/kaggle/input/skin-disease-dataset/Skin_Disease_Dataset/Train"
data_dir_test = "/kaggle/input/skin-disease-dataset/Skin_Disease_Dataset/Test"
data_dir_val = "/kaggle/input/skin-disease-dataset/Skin_Disease_Dataset/Val"

# %%
# data_dir_train = "/kaggle/input/vegetable-image-dataset/Vegetable Images/test"
# data_dir_test = "/kaggle/input/vegetable-image-dataset/Vegetable Images/train"

# %%
# Data transformations
data_transforms = {
    "train": transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    "val": transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    "test": transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# Datasets
train_dataset = datasets.ImageFolder(root=data_dir_train, transform=data_transforms["train"])
val_dataset = datasets.ImageFolder(root=data_dir_val, transform=data_transforms["val"])
test_dataset = datasets.ImageFolder(root=data_dir_test, transform=data_transforms["test"])

# DataLoaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=2)

# Class information
class_names = train_dataset.classes
num_classes = len(class_names)

print(f"Classes: {class_names}")
print(f"Number of classes: {num_classes}")
print(f"Number of training samples: {len(train_dataset)}")
print(f"Number of validation samples: {len(val_dataset)}")
print(f"Number of test samples: {len(test_dataset)}")
# Out:
# Classes: ['1. Eczema', '10. Warts Molluscum and other Viral Infections', '2. Melanoma', '3. Atopic Dermatitis', '4. Basal Cell Carcinoma (BCC)', '5. Melanocytic Nevi (NV)', '6. Benign Keratosis-like Lesions (BKL)', '7. Psoriasis pictures Lichen Planus and related diseases', '8. Seborrheic Keratoses and other Benign Tumors', '9. Tinea Ringworm Candidiasis and other Fungal Infections']
# Number of classes: 10
# Number of training samples: 19003
# Number of validation samples: 2711
# Number of test samples: 5439

# %%
print(class_names)
num_classes
# Out:
# ['1. Eczema', '10. Warts Molluscum and other Viral Infections', '2. Melanoma', '3. Atopic Dermatitis', '4. Basal Cell Carcinoma (BCC)', '5. Melanocytic Nevi (NV)', '6. Benign Keratosis-like Lesions (BKL)', '7. Psoriasis pictures Lichen Planus and related diseases', '8. Seborrheic Keratoses and other Benign Tumors', '9. Tinea Ringworm Candidiasis and other Fungal Infections']
# 10

# %%
from collections import Counter

def plot_class_distribution(dataset, class_names):
    labels = [label for _, label in dataset]
    class_counts = Counter(labels)
    class_indices = list(class_counts.keys())
    class_values = list(class_counts.values())
    
    plt.figure(figsize=(12, 6))
    sns.barplot(x=[class_names[idx] for idx in class_indices], y=class_values, palette="viridis")
    plt.title("Class Distribution in Training Data", fontsize=14)
    plt.xlabel("Class", fontsize=12)
    plt.ylabel("Frequency", fontsize=12)
    plt.xticks(rotation=45, fontsize=10)
    plt.tight_layout()
    plt.show()

plot_class_distribution(train_dataset, class_names)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 18
#      15     plt.tight_layout()
#      16     plt.show()
# ---> 18 plot_class_distribution(train_dataset, class_names)
#
# Cell In[7], line 4, in plot_class_distribution(dataset, class_names)
#       3 def plot_class_distribution(dataset, class_names):
# ----> 4     labels = [label for _, label in dataset]
#       5     class_counts = Counter(labels)
#       6     class_indices = list(class_counts.keys())
#
# Cell In[7], line 4, in <listcomp>(.0)
#       3 def plot_class_distribution(dataset, class_names):
# ----> 4     labels = [label for _, label in dataset]
#       5     class_counts = Counter(labels)
#       6     class_indices = list(class_counts.keys())
#
# File /opt/conda/lib/python3.10/site-packages/torchvision/datasets/folder.py:245, in DatasetFolder.__getitem__(self, index)
#     237 """
#     238 Args:
#     239     index (int): Index
#    (...)
#     242     tuple: (sample, target) where target is class_index of the target class.
#     243 """
#     244 path, target = self.samples[index]
# --> 245 sample = self.loader(path)
#     246 if self.transform is not None:
#     247     sample = self.transform(sample)
#
# File /opt/conda/lib/python3.10/site-packages/torchvision/datasets/folder.py:284, in default_loader(path)
#     282     return accimage_loader(path)
#     283 else:
# --> 284     return pil_loader(path)
#
# File /opt/conda/lib/python3.10/site-packages/torchvision/datasets/folder.py:263, in pil_loader(path)
#     260 def pil_loader(path: str) -> Image.Image:
#     261     # open path as file to avoid ResourceWarning (https://github.com/python-pillow/Pillow/issues/835)
#     262     with open(path, "rb") as f:
# --> 263         img = Image.open(f)
#     264         return img.convert("RGB")
#
# File /opt/conda/lib/python3.10/site-packages/PIL/Image.py:3480, in open(fp, mode, formats)
#    3477     fp = io.BytesIO(fp.read())
#    3478     exclusive_fp = True
# -> 3480 prefix = fp.read(16)
#    3482 preinit()
#    3484 warning_messages: list[str] = []
#
# KeyboardInterrupt:

# %%
from torch.utils.data import WeightedRandomSampler

# Tính trọng số mẫu
class_sample_counts = Counter([label for _, label in train_dataset])
weights = 1. / np.array([class_sample_counts[i] for i in range(num_classes)])
sample_weights = [weights[label] for _, label in train_dataset]

# Sampler
sampler = WeightedRandomSampler(sample_weights, len(sample_weights), replacement=True)
train_loader = DataLoader(train_dataset, batch_size=64, sampler=sampler, num_workers=2)

# %%
data_iter = iter(train_loader)
images, labels = next(data_iter)

# Hiển thị hình ảnh
fig, ax = plt.subplots(nrows=3, ncols=10, figsize=(20, 8))
for idx in range(30):
    row, col = divmod(idx, 10)
    ax[row, col].imshow(np.transpose(images[idx].numpy(), (1, 2, 0)))
    ax[row, col].set_title(str(class_names[labels[idx]]), fontsize=8)
    ax[row, col].axis('off')
plt.tight_layout()
plt.show()

# %%
# Tính trọng số cho các lớp
y_train = [label for _, labels in train_loader for label in labels.numpy()]
class_weights = compute_class_weight(class_weight="balanced", classes=np.arange(num_classes), y=y_train)
class_weights = torch.tensor(class_weights, dtype=torch.float).to("cuda")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch
import torch.nn as nn

# Định nghĩa lại mô hình
class VGG16PowerUp(nn.Module):
    def __init__(self, num_classes=1000):
        super(VGG16PowerUp, self).__init__()
        self.features = nn.Sequential(
            # Block 1
            nn.Conv2d(3, 16, kernel_size=3, padding=1),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(16, 16, kernel_size=3, padding=1),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            # Block 2
            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(32, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            # Block 3
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            # Block 4
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            # Block 5
            nn.Conv2d(128, 192, kernel_size=3, padding=1),  # Giảm từ 256 xuống 192
            nn.BatchNorm2d(192),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(192, 256, kernel_size=3, padding=1),  # Giảm từ 512 xuống 256
            nn.BatchNorm2d(256),
            nn.LeakyReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        
        # Global Average Pooling
        self.global_pool = nn.AdaptiveAvgPool2d((1, 1))
        
        # Classifier
        self.classifier = nn.Sequential(
            nn.Linear(256, 256),  # Giảm từ 512 xuống 256
            nn.LeakyReLU(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(256, num_classes),
        )
        
        self._initialize_weights()

    def forward(self, x):
        x = self.features(x)
        x = self.global_pool(x)
        x = torch.flatten(x, 1)  # Flatten sau GAP
        x = self.classifier(x)
        return x

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='leaky_relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight)  # Thay thế bằng Xavier Normal
                nn.init.constant_(m.bias, 0)

# Khởi tạo mô hình
num_classes = 10  # Sửa thành số class trong bài toán của bạn
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_powerup = VGG16PowerUp(num_classes=num_classes).to(device)


def count_parameters(model):
    """Hàm đếm số tham số của mô hình."""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# In số tham số
print(f"Số tham số sau khi tăng sức mạnh: {count_parameters(model_powerup):,}")
# Out:
# Số tham số sau khi tăng sức mạnh: 1,027,738

# %%
import os

# Tạo thư mục nếu chưa tồn tại
save_dir = "/kaggle/working/check"
os.makedirs(save_dir, exist_ok=True)

# %%
import wandb
import timm

# Khởi tạo Wandb
wandb.init(
    project="skin-disease-classification",
    id="VGG-16-skin-last-weak",
    config={
        "epochs": 5,
        "batch_size": 64,
        "learning_rate": 0.001,
        "optimizer": "Adam",
        "model": "vit_tiny_patch16_224",
        "num_classes": num_classes
    }
)


# Lấy config từ Wandb
config = wandb.config

# Thiết lập thiết bị
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Khởi tạo mô hình và các thành phần
model = model_powerup.to(device)
# model = model_from_scratch_2
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)
# Tạo dataloaders dictionary
dataloaders = {
    "train": train_loader,
    "val": val_loader
}


# checkpoint = torch.load("/kaggle/working/check/checkpoint4.pth", map_location=device)
# model.load_state_dict(checkpoint['model_state_dict'])
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# start_epoch = checkpoint['epoch']
# Out:
# Finishing last run (ID:VGG-16-skin-last-weak) before initializing another...
#  View run <strong style="color:#cdcd00">VGG-16-skin-last-weak</strong> at: <a href='https://wandb.ai/hoanoc321-dswfvsfv/skin-disease-classification/runs/VGG-16-skin-last-weak' target="_blank">https://wandb.ai/hoanoc321-dswfvsfv/skin-disease-classification/runs/VGG-16-skin-last-weak</a><br/> View project at: <a href='https://wandb.ai/hoanoc321-dswfvsfv/skin-disease-classification' target="_blank">https://wandb.ai/hoanoc321-dswfvsfv/skin-disease-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241209_100920-VGG-16-skin-last-weak/logs</code>
# Successfully finished last run (ID:VGG-16-skin-last-weak). Initializing new run:<br/>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/kaggle/working/wandb/run-20241209_101008-VGG-16-skin-last-weak</code>
# Syncing run <strong><a href='https://wandb.ai/hoanoc321-dswfvsfv/skin-disease-classification/runs/VGG-16-skin-last-weak' target="_blank">VGG-16-skin-last-weak</a></strong> to <a href='https://wandb.ai/hoanoc321-dswfvsfv/skin-disease-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hoanoc321-dswfvsfv/skin-disease-classification' target="_blank">https://wandb.ai/hoanoc321-dswfvsfv/skin-disease-classification</a>
#  View run at <a href='https://wandb.ai/hoanoc321-dswfvsfv/skin-disease-classification/runs/VGG-16-skin-last-weak' target="_blank">https://wandb.ai/hoanoc321-dswfvsfv/skin-disease-classification/runs/VGG-16-skin-last-weak</a>

# %%
def train_and_evaluate_with_wandb(model, dataloaders, criterion, optimizer, device, num_epochs):
    train_loss_history, train_acc_history = [], []
    val_loss_history, val_acc_history = [], []
    best_val_acc = 0.0  # Biến để lưu trữ giá trị val accuracy tốt nhất

    for epoch in range(num_epochs):
        print(f"Epoch {epoch + 1}/{num_epochs}")
        wandb.log({"epoch": epoch + 1})
        
        # Pha train được thực hiện mọi epoch
        model.train()
        running_loss, running_corrects = 0.0, 0

        for batch_idx, (inputs, labels) in enumerate(dataloaders['train']):
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

            with torch.set_grad_enabled(True):
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)

                loss.backward()
                optimizer.step()

                #Tính Grad Norm
                total_norm = 0
                for p in model.parameters():
                    if p.grad is not None:
                        total_norm += p.grad.norm().item() ** 2
                total_norm = total_norm ** 0.5
                wandb.log({"grad_norm": total_norm})

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            # Log hình ảnh từ batch đầu tiên
            if batch_idx == 0:
                images = wandb.Image(inputs[:8].cpu(), caption="Ground Truth: {}".format(labels[:8].cpu()))
                wandb.log({"samples": images})

        # Tính toán loss và accuracy sau pha train
        train_loss = running_loss / len(dataloaders['train'].dataset)
        train_acc = running_corrects.double() / len(dataloaders['train'].dataset)

        train_loss_history.append(train_loss)
        train_acc_history.append(train_acc.item())
        wandb.log({
            "train_loss": train_loss,
            "train_accuracy": train_acc.item()
        })

        print(f"Train Loss: {train_loss:.4f} Acc: {train_acc:.4f}")

        # Pha validation chỉ chạy mỗi 5 epoch
        if epoch % 5 == 4:
            model.eval()
            running_loss, running_corrects = 0.0, 0

            for batch_idx, (inputs, labels) in enumerate(dataloaders['val']):
                inputs, labels = inputs.to(device), labels.to(device)

                with torch.set_grad_enabled(False):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    _, preds = torch.max(outputs, 1)

                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)

            # Tính toán loss và accuracy sau pha validation
            val_loss = running_loss / len(dataloaders['val'].dataset)
            val_acc = running_corrects.double() / len(dataloaders['val'].dataset)

            val_loss_history.append(val_loss)
            val_acc_history.append(val_acc.item())
            wandb.log({
                "val_loss": val_loss,
                "val_accuracy": val_acc.item()
            })

            print(f"Val Loss: {val_loss:.4f} Acc: {val_acc:.4f}")

            # Kiểm tra và lưu mô hình nếu val accuracy cao nhất
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                model_path = f"/kaggle/working/best_model_vit_16_tiny_custom_epoch_{epoch + 1}.pth"  # Tên file có index của epoch
                torch.save(model.state_dict(), model_path)
                wandb.save(model_path)
                print(f"Best model saved at epoch {epoch + 1} with val accuracy {best_val_acc:.4f}")

    # Lưu mô hình cuối cùng vào Wandb
    torch.save(model.state_dict(), "final_model_weak_custom.pth")
    wandb.save("final_model_weak_pretrain.pth")
    print("Final model saved.")

    return train_loss_history, train_acc_history, val_loss_history, val_acc_history

# %%
# Huấn luyện và đánh giá mô hình
train_loss_history, train_acc_history, val_loss_history, val_acc_history = train_and_evaluate_with_wandb(
    model=model,
    dataloaders=dataloaders,
    criterion=criterion,
    optimizer=optimizer,
    device=device,
    num_epochs=100
)
# Out:
# Epoch 1/100
# Train Loss: 1.8124 Acc: 0.3130
# Epoch 2/100
# Train Loss: 1.5611 Acc: 0.3894
# Epoch 3/100
# Train Loss: 1.4259 Acc: 0.4337
# Epoch 4/100
# Train Loss: 1.3567 Acc: 0.4568
# Epoch 5/100
# Train Loss: 1.3054 Acc: 0.4791
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# Val Loss: 1.6325 Acc: 0.4589
# Best model saved at epoch 5 with val accuracy 0.4589
# Epoch 6/100
# Train Loss: 1.2725 Acc: 0.4932
# Epoch 7/100
# Train Loss: 1.2435 Acc: 0.5003
# Epoch 8/100
# Train Loss: 1.2204 Acc: 0.5129
# Epoch 9/100
# Train Loss: 1.2021 Acc: 0.5227
# Epoch 10/100
# Train Loss: 1.1872 Acc: 0.5313
# Val Loss: 1.0668 Acc: 0.5754
# Best model saved at epoch 10 with val accuracy 0.5754
# Epoch 11/100
# Train Loss: 1.1934 Acc: 0.5251
# Epoch 12/100
# Train Loss: 1.1615 Acc: 0.5392
# Epoch 13/100
# Train Loss: 1.1579 Acc: 0.5452
# Epoch 14/100
# Train Loss: 1.1382 Acc: 0.5487
# Epoch 15/100
# Train Loss: 1.1313 Acc: 0.5532
# Val Loss: 0.9361 Acc: 0.6134
# Best model saved at epoch 15 with val accuracy 0.6134
# Epoch 16/100
# Train Loss: 1.1336 Acc: 0.5539
# Epoch 17/100
# Train Loss: 1.1183 Acc: 0.5552
# Epoch 18/100
# Train Loss: 1.1213 Acc: 0.5584
# Epoch 19/100
# Train Loss: 1.0949 Acc: 0.5699
# Epoch 20/100
# Train Loss: 1.1005 Acc: 0.5682
# Val Loss: 1.3523 Acc: 0.5308
# Epoch 21/100
# Train Loss: 1.1089 Acc: 0.5635
# Epoch 22/100
# Train Loss: 1.0902 Acc: 0.5685
# Epoch 23/100
# Train Loss: 1.0749 Acc: 0.5774
# Epoch 24/100
# Train Loss: 1.0676 Acc: 0.5802
# Epoch 25/100
# Train Loss: 1.0449 Acc: 0.5900
# Val Loss: 0.8695 Acc: 0.6621
# Best model saved at epoch 25 with val accuracy 0.6621
# Epoch 26/100
# Train Loss: 1.0612 Acc: 0.5875
# Epoch 27/100
# Train Loss: 1.0435 Acc: 0.5931
# Epoch 28/100
# Train Loss: 1.0502 Acc: 0.5884
# Epoch 29/100
# Train Loss: 1.0384 Acc: 0.5959
# Epoch 30/100
# Train Loss: 1.0202 Acc: 0.6005
# Val Loss: 0.8615 Acc: 0.6492
# Epoch 31/100
# Train Loss: 1.0069 Acc: 0.6071
# Epoch 32/100
# Train Loss: 1.0129 Acc: 0.6044
# Epoch 33/100
# Train Loss: 1.0165 Acc: 0.6040
# Epoch 34/100
# Train Loss: 0.9933 Acc: 0.6125
# Epoch 35/100
# Train Loss: 0.9846 Acc: 0.6168
# Val Loss: 0.8059 Acc: 0.6898
# Best model saved at epoch 35 with val accuracy 0.6898
# Epoch 36/100
# Train Loss: 0.9780 Acc: 0.6213
# Epoch 37/100
# Train Loss: 0.9726 Acc: 0.6225
# Epoch 38/100
# Train Loss: 0.9589 Acc: 0.6281
# Epoch 39/100
# Train Loss: 0.9543 Acc: 0.6343
# Epoch 40/100
# Train Loss: 0.9673 Acc: 0.6304
# Val Loss: 0.8777 Acc: 0.6625
# Epoch 41/100
# Train Loss: 0.9656 Acc: 0.6285
# Epoch 42/100
# Train Loss: 0.9389 Acc: 0.6392
# Epoch 43/100
# Train Loss: 0.9290 Acc: 0.6456
# Epoch 44/100
# Train Loss: 0.9268 Acc: 0.6451
# Epoch 45/100
# Train Loss: 0.9193 Acc: 0.6463
# Val Loss: 0.7508 Acc: 0.7141
# Best model saved at epoch 45 with val accuracy 0.7141
# Epoch 46/100
# Train Loss: 0.9048 Acc: 0.6557
# Epoch 47/100
# Train Loss: 0.8975 Acc: 0.6563
# Epoch 48/100
# Train Loss: 0.8927 Acc: 0.6602
# Epoch 49/100
# Train Loss: 0.8846 Acc: 0.6613
# Epoch 50/100
# Train Loss: 0.8896 Acc: 0.6612
# Val Loss: 0.7441 Acc: 0.7270
# Best model saved at epoch 50 with val accuracy 0.7270
# Epoch 51/100
# Train Loss: 0.8833 Acc: 0.6603
# Epoch 52/100
# Train Loss: 0.8646 Acc: 0.6671
# Epoch 53/100
# Train Loss: 0.8761 Acc: 0.6681
# Epoch 54/100
# Train Loss: 0.8692 Acc: 0.6673
# Epoch 55/100
# Train Loss: 0.8458 Acc: 0.6797
# Val Loss: 0.7498 Acc: 0.7219
# Epoch 56/100
# Train Loss: 0.8378 Acc: 0.6794
# Epoch 57/100
# Train Loss: 0.8489 Acc: 0.6752
# Epoch 58/100
# Train Loss: 0.8490 Acc: 0.6754
# Epoch 59/100
# Train Loss: 0.8240 Acc: 0.6818
# Epoch 60/100
# Train Loss: 0.8132 Acc: 0.6937
# Val Loss: 0.7179 Acc: 0.7363
# Best model saved at epoch 60 with val accuracy 0.7363
# Epoch 61/100
# Train Loss: 0.8138 Acc: 0.6925
# Epoch 62/100
# Train Loss: 0.8106 Acc: 0.6908
# Epoch 63/100
# Train Loss: 0.8134 Acc: 0.6902
# Epoch 64/100
# Train Loss: 0.7867 Acc: 0.7000
# Epoch 65/100
# Train Loss: 0.7904 Acc: 0.6998
# Val Loss: 0.7209 Acc: 0.7433
# Best model saved at epoch 65 with val accuracy 0.7433
# Epoch 66/100
# Train Loss: 0.7943 Acc: 0.6980
# Epoch 67/100
# Train Loss: 0.7714 Acc: 0.7078
# Epoch 68/100
# Train Loss: 0.7703 Acc: 0.7109
# Epoch 69/100
# Train Loss: 0.7652 Acc: 0.7106
# Epoch 70/100
# Train Loss: 0.7679 Acc: 0.7086
# Val Loss: 0.7064 Acc: 0.7436
# Best model saved at epoch 70 with val accuracy 0.7436
# Epoch 71/100
# Train Loss: 0.7521 Acc: 0.7200
# Epoch 72/100
# Train Loss: 0.7468 Acc: 0.7216
# Epoch 73/100
# Train Loss: 0.7329 Acc: 0.7230
# Epoch 74/100
# Train Loss: 0.7339 Acc: 0.7230
# Epoch 75/100
# Train Loss: 0.7256 Acc: 0.7285
# Val Loss: 0.6716 Acc: 0.7639
# Best model saved at epoch 75 with val accuracy 0.7639
# Epoch 76/100
# Train Loss: 0.7229 Acc: 0.7288
# Epoch 77/100
# Train Loss: 0.7242 Acc: 0.7324
# Epoch 78/100
# Train Loss: 0.7114 Acc: 0.7337
# Epoch 79/100
# Train Loss: 0.7044 Acc: 0.7395
# Epoch 80/100
# Train Loss: 0.7082 Acc: 0.7368
# Val Loss: 0.6743 Acc: 0.7613
# Epoch 81/100
# Train Loss: 0.6913 Acc: 0.7427
# Epoch 82/100
# Train Loss: 0.6931 Acc: 0.7397
# Epoch 83/100
# Train Loss: 0.6835 Acc: 0.7443
# Epoch 84/100
# Train Loss: 0.6945 Acc: 0.7379
# Epoch 85/100
# Train Loss: 0.6714 Acc: 0.7533
# Val Loss: 0.6961 Acc: 0.7503
# Epoch 86/100
# Train Loss: 0.6589 Acc: 0.7534
# Epoch 87/100
# Train Loss: 0.6620 Acc: 0.7526
# Epoch 88/100
# Train Loss: 0.6571 Acc: 0.7559
# Epoch 89/100
# Train Loss: 0.6571 Acc: 0.7576
# Epoch 90/100
# Train Loss: 0.6590 Acc: 0.7570
# Val Loss: 0.6442 Acc: 0.7783
# Best model saved at epoch 90 with val accuracy 0.7783
# Epoch 91/100
# Train Loss: 0.6387 Acc: 0.7625
# Epoch 92/100
# Train Loss: 0.6271 Acc: 0.7676
# Epoch 93/100
# Train Loss: 0.6289 Acc: 0.7646
# Epoch 94/100
# Train Loss: 0.6332 Acc: 0.7648
# Epoch 95/100
# Train Loss: 0.6202 Acc: 0.7704
# Val Loss: 0.6620 Acc: 0.7735
# Epoch 96/100
# Train Loss: 0.6177 Acc: 0.7704
# Epoch 97/100
# Train Loss: 0.6103 Acc: 0.7762
# Epoch 98/100
# Train Loss: 0.6249 Acc: 0.7718
# Epoch 99/100
# Train Loss: 0.6007 Acc: 0.7784
# Epoch 100/100
# Train Loss: 0.5989 Acc: 0.7796
# Val Loss: 0.6477 Acc: 0.7794
# Best model saved at epoch 100 with val accuracy 0.7794
# Final model saved.

# %%
from sklearn.metrics import classification_report, accuracy_score, average_precision_score, confusion_matrix
import pandas as pd

def evaluate_on_test(model, test_loader, device, class_names):
    model.eval()  # Chuyển sang chế độ đánh giá
    all_preds = []
    all_labels = []
    all_probs = []

    print("Evaluating on test dataset...")
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            probs = torch.softmax(outputs, dim=1)
            _, preds = torch.max(probs, 1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    # Tính các chỉ số tổng thể
    accuracy = accuracy_score(all_labels, all_preds)
    report = classification_report(
        all_labels, 
        all_preds, 
        target_names=class_names, 
        digits=4, 
        output_dict=True
    )
    precision = report['weighted avg']['precision']
    recall = report['weighted avg']['recall']
    f1 = report['weighted avg']['f1-score']

    # mAP (Mean Average Precision)
    binarized_labels = pd.get_dummies(all_labels).to_numpy()
    mAP = average_precision_score(binarized_labels, all_probs, average='macro')

    # Log các chỉ số tổng thể lên WandB
    wandb.log({
        "test_accuracy": accuracy,
        "test_precision_weighted": precision,
        "test_recall_weighted": recall,
        "test_f1_weighted": f1,
        "test_mAP": mAP
    })

    # Log các chỉ số theo từng lớp
    for class_name, metrics in report.items():
        if class_name in class_names:  # Chỉ log cho các lớp, bỏ qua "accuracy", "weighted avg", "macro avg"
            wandb.log({
                f"test_precision_{class_name}": metrics['precision'],
                f"test_recall_{class_name}": metrics['recall'],
                f"test_f1_{class_name}": metrics['f1-score']
            })

    # In các chỉ số tổng thể
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision (weighted): {precision:.4f}, Recall (weighted): {recall:.4f}, F1-score (weighted): {f1:.4f}, mAP: {mAP:.4f}")

    # Confusion matrix
    cm = confusion_matrix(all_labels, all_preds)
    cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)
    print("Confusion Matrix:")
    print(cm_df)
    wandb.log({"test_confusion_matrix": wandb.Table(dataframe=cm_df)})

    # Hiển thị một số mẫu đúng và sai
    print("\nSample Predictions:")
    correct_samples = [(i, p) for i, p in enumerate(zip(all_labels, all_preds)) if p[0] == p[1]]
    incorrect_samples = [(i, p) for i, p in enumerate(zip(all_labels, all_preds)) if p[0] != p[1]]

    print("Correct Predictions (first 5):")
    for idx, (true, pred) in correct_samples[:5]:
        print(f"Sample {idx}: True = {class_names[true]}, Pred = {class_names[pred]}")

    print("Incorrect Predictions (first 5):")
    for idx, (true, pred) in incorrect_samples[:5]:
        print(f"Sample {idx}: True = {class_names[true]}, Pred = {class_names[pred]}")

    return {
        "accuracy": accuracy,
        "precision_weighted": precision,
        "recall_weighted": recall,
        "f1_score_weighted": f1,
        "mAP": mAP,
        "class_metrics": report
    }


# Gọi evaluate_on_test sau khi huấn luyện
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=2)
dataloaders["test"] = test_dataloader



# Đánh giá trên test set
test_metrics = evaluate_on_test(model, dataloaders["test"], device, class_names)
print(f"Test Set Metrics:\n{test_metrics}")
wandb.log({"test_metrics": test_metrics})

# %%
# Đánh giá trên test set như ở trên
def evaluate_on_test(model, dataloader, device, class_names):
    model.eval()
    test_loss, test_corrects = 0.0, 0
    all_preds, all_labels = [], []

    for inputs, labels in dataloader:
        inputs, labels = inputs.to(device), labels.to(device)

        with torch.no_grad():
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            _, preds = torch.max(outputs, 1)

            test_loss += loss.item() * inputs.size(0)
            test_corrects += torch.sum(preds == labels.data)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    test_epoch_loss = test_loss / len(dataloader.dataset)
    test_epoch_acc = test_corrects.double() / len(dataloader.dataset)

    # Đánh giá chi tiết với các chỉ số như precision, recall, F1-score
    report = classification_report(all_labels, all_preds, output_dict=True)
    test_precision = report['weighted avg']['precision']
    test_recall = report['weighted avg']['recall']
    test_f1 = report['weighted avg']['f1-score']

    # Log các chỉ số chi tiết lên WandB
    wandb.log({
        "test_loss": test_epoch_loss,
        "test_accuracy": test_epoch_acc,
        "test_precision_weighted": test_precision,
        "test_recall_weighted": test_recall,
        "test_f1_weighted": test_f1
    })

    return {
        "loss": test_epoch_loss,
        "accuracy": test_epoch_acc,
        "precision": test_precision,
        "recall": test_recall,
        "f1": test_f1
    }

# Đánh giá mô hình trên test set
test_metrics = evaluate_on_test(model, dataloaders["test"], device, class_names)
wandb.log({"test_metrics": test_metrics})
